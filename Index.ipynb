# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# x=np.arange(-3.14,3.14,0.5)
# y=np.tan(x)
plt.figure(figsize=(10,3),dpi=1080)
x=np.arange(0,10,0.2)
plt.plot(x,x**2+2*x+1)
# plt.plot(x,x**2.5,label='x**2')
# plt.plot(x,x**x,label='x**x')
# plt.plot(x,y,label='tan(x)',color='red',linewidth=1,linestyle='--', marker='x',markersize=10, markeredgecolor='blue')
# plt.plot(x,y,'rx--',label='tan(x)')
# plt.xticks([-1.3,0,1.3])
# plt.yticks([-1.732,1.732,0])
# plt.legend()
# plt.title('Graph of tan',fontdict={'fontname':'sans','fontsize':50})
# plt.xlabel('radians(as x)',fontdict={'fontname':'sans','fontsize':20})
# plt.ylabel('tan(x)',fontdict={'fontname':'sans','fontsize':40})
plt.savefig('fig.png',dpi=300)
plt.show()

# %%
labels=['A','B','C','D']
values=[5,9,21,6]
bars=plt.bar(labels,values,label='123')
plt.figure(figsize=(3,5),dpi=300)
# plt.figure(figsize=(10,3),dpi=1080)
# bars[0].set_hatch('O')
# bars[1].set_hatch('o')
# bars[2].set_hatch('+')
# bars[3].set_hatch('*')
pattern=['O','o','+','*']
for bar in bars:
    bar.set_hatch(pattern.pop(0))

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
